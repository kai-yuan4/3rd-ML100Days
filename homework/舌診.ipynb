# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/Users/reversi/Downloads/104683.BMP')
img.shape
# Out:
# (1000, 1280, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[128, 145, 212],
#         [134, 162, 220],
#         [126, 162, 213],
#         ...,
#         [127, 168, 209],
#         [125, 168, 209],
#         [127, 170, 211]],
#
#        [[130, 144, 213],
#         [134, 159, 218],
#         [126, 162, 213],
#         ...,
#         [126, 169, 210],
#         [123, 169, 209],
#         [124, 170, 210]],
#
#        [[127, 143, 212],
#         [130, 157, 218],
#         [125, 160, 214],
#         ...,
#         [123, 169, 209],
#         [122, 168, 208],
#         [122, 168, 208]],
#
#        ...,
#
#        [[ 66,  65,  71],
#         [ 72,  75,  76],
#         [ 69,  75,  74],
#         ...,
#         [ 96, 132, 129],
#         [132, 169, 164],
#         [175, 212, 207]],
#
#        [[ 65,  67,  78],
#         [ 64,  71,  76],
#         [ 63,  75,  74],
#         ...,
#         [ 98, 135, 129],
#         [129, 166, 160],
#         [167, 204, 198]],
#
#        [[ 67,  73,  82],
#         [ 64,  76,  80],
#         [ 62,  78,  77],
# ...
